# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('wine.csv')
df
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
df.head()
# Out:
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             178 non-null    int64
#  1   Alcohol          178 non-null    float64
#  2   Malic            178 non-null    float64
#  3   Ash              178 non-null    float64
#  4   Alcalinity       178 non-null    float64
#  5   Magnesium        178 non-null    int64
#  6   Phenols          178 non-null    float64
#  7   Flavanoids       178 non-null    float64
#  8   Nonflavanoids    178 non-null    float64
#  9   Proanthocyanins  178 non-null    float64
#  10  Color            178 non-null    float64
#  11  Hue              178 non-null    float64
#  12  Dilution         178 non-null    float64
#  13  Proline          178 non-null    int64
# dtypes: float64(11), int64(3)
# memory usage: 19.6 KB

# %%
df.describe()
# Out:
#              Type     Alcohol       Malic         Ash  Alcalinity   Magnesium  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoids  Proanthocyanins       Color  \
# count  178.000000  178.000000     178.000000       178.000000  178.000000
# mean     2.295112    2.029270       0.361854         1.590899    5.058090
# ...

# %%
df.isnull().sum()
# Out:
# Type               0
# Alcohol            0
# Malic              0
# Ash                0
# Alcalinity         0
# Magnesium          0
# Phenols            0
# Flavanoids         0
# Nonflavanoids      0
# Proanthocyanins    0
# Color              0
# Hue                0
# Dilution           0
# Proline            0
# dtype: int64

# %%
df.shape
# Out:
# (178, 14)

# %%
from sklearn.model_selection import train_test_split
X = df.drop('Type', axis=1)
y = df['Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.20,random_state=42)

# %%
sns.pairplot(X_train)

# %% [markdown]
# # 1--> Normalized data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaler = scaler.fit_transform(X)
X_scaler
# Out:
# array([[ 1.51861254, -0.5622498 ,  0.23205254, ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [ 0.24628963, -0.49941338, -0.82799632, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [ 0.19687903,  0.02123125,  1.10933436, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 0.33275817,  1.74474449, -0.38935541, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 0.20923168,  0.22769377,  0.01273209, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.39508604,  1.58316512,  1.36520822, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
rows=X_scaler.T
covariance_matrix=np.cov(rows)
covariance_matrix
# Out:
# array([[ 1.00564972,  0.09493026,  0.21273976, -0.31198788,  0.27232816,
#          0.29073446,  0.23815287, -0.15681042,  0.13747022,  0.549451  ,
#         -0.07215255,  0.07275191,  0.64735687],
#        [ 0.09493026,  1.00564972,  0.16497228,  0.29013035, -0.05488343,
#         -0.3370606 , -0.41332866,  0.29463237, -0.22199334,  0.25039204,
#         -0.56446685, -0.37079354, -0.19309537],
#        [ 0.21273976,  0.16497228,  1.00564972,  0.44587209,  0.28820583,
#          0.12970824,  0.11572743,  0.1872826 ,  0.00970647,  0.2603499 ,
#         -0.07508874,  0.00393333,  0.22488969],
#        [-0.31198788,  0.29013035,  0.44587209,  1.00564972, -0.0838039 ,
#         -0.32292752, -0.353355  ,  0.36396647, -0.19844168,  0.01883781,
#         -0.27550299, -0.27833221, -0.44308618],
#        [ 0.27232816, -0.05488343,  0.28820583, -0.0838039 ,  1.00564972,
#          0.21561254,  0.19688989, -0.25774204,  0.23777643,  0.20107967,
#          0.05571118,  0.06637684,  0.39557317],
# ...

# %%
eig_values,eig_vectors=np.linalg.eig(covariance_matrix)

# %%
eig_values,eig_vectors
# Out:
# (array([4.73243698, 2.51108093, 1.45424187, 0.92416587, 0.85804868,
#         0.64528221, 0.55414147, 0.10396199, 0.35046627, 0.16972374,
#         0.29051203, 0.22706428, 0.25232001]),
#  array([[-0.1443294 , -0.48365155,  0.20738262, -0.0178563 ,  0.26566365,
#          -0.21353865, -0.05639636,  0.01496997, -0.39613926,  0.26628645,
#           0.50861912, -0.22591696,  0.21160473],
#         [ 0.24518758, -0.22493093, -0.08901289,  0.53689028, -0.03521363,
#          -0.53681385,  0.42052391,  0.02596375, -0.06582674, -0.12169604,
#          -0.07528304,  0.07648554, -0.30907994],
#         [ 0.00205106, -0.31606881, -0.6262239 , -0.21417556,  0.14302547,
#          -0.15447466, -0.14917061, -0.14121803,  0.17026002,  0.04962237,
#          -0.30769445, -0.49869142, -0.02712539],
#         [ 0.23932041,  0.0105905 , -0.61208035,  0.06085941, -0.06610294,
#           0.10082451, -0.28696914,  0.09168285, -0.42797018,  0.05574287,
#           0.20044931,  0.47931378,  0.05279942],
# ...

# %%
print(eig_values)
# Out:
# [4.73243698 2.51108093 1.45424187 0.92416587 0.85804868 0.64528221
#  0.55414147 0.10396199 0.35046627 0.16972374 0.29051203 0.22706428
#  0.25232001]

# %%
print(eig_vectors)
# Out:
# [[-0.1443294  -0.48365155  0.20738262 -0.0178563   0.26566365 -0.21353865
#   -0.05639636  0.01496997 -0.39613926  0.26628645  0.50861912 -0.22591696
#    0.21160473]
#  [ 0.24518758 -0.22493093 -0.08901289  0.53689028 -0.03521363 -0.53681385
#    0.42052391  0.02596375 -0.06582674 -0.12169604 -0.07528304  0.07648554
#   -0.30907994]
#  [ 0.00205106 -0.31606881 -0.6262239  -0.21417556  0.14302547 -0.15447466
#   -0.14917061 -0.14121803  0.17026002  0.04962237 -0.30769445 -0.49869142
#   -0.02712539]
#  [ 0.23932041  0.0105905  -0.61208035  0.06085941 -0.06610294  0.10082451
#   -0.28696914  0.09168285 -0.42797018  0.05574287  0.20044931  0.47931378
#    0.05279942]
#  [-0.14199204 -0.299634   -0.13075693 -0.35179658 -0.72704851 -0.03814394
#    0.3228833   0.05677422  0.15636143 -0.06222011  0.27140257  0.07128891
#    0.06787022]
#  [-0.39466085 -0.06503951 -0.14617896  0.19806835  0.14931841  0.0841223
#   -0.02792498 -0.46390791  0.40593409  0.30388245  0.28603452  0.30434119
# ...

# %%
print(eig_values)
# Out:
# [4.73243698 2.51108093 1.45424187 0.92416587 0.85804868 0.64528221
#  0.55414147 0.10396199 0.35046627 0.16972374 0.29051203 0.22706428
#  0.25232001]

# %%
for i in range(len(eig_values)):
    print(eig_values[i]/sum(eig_values))
# Out:
# 0.36198848099926345
# 0.19207490257008947
# 0.1112363053624998
# 0.07069030182714031
# 0.065632936796486
# 0.049358233192225646
# 0.042386793226233205
# 0.007952148898994489
# 0.026807489483788614
# 0.012982325756042148
# 0.022221534047897094
# 0.01736835689989915
# 0.01930019093944078

# %%
# the oth row contains the highest information gain (36%)

# %%
eig_vectors.T
# Out:
# array([[-0.1443294 ,  0.24518758,  0.00205106,  0.23932041, -0.14199204,
#         -0.39466085, -0.4229343 ,  0.2985331 , -0.31342949,  0.0886167 ,
#         -0.29671456, -0.37616741, -0.28675223],
#        [-0.48365155, -0.22493093, -0.31606881,  0.0105905 , -0.299634  ,
#         -0.06503951,  0.00335981, -0.02877949, -0.03930172, -0.52999567,
#          0.27923515,  0.16449619, -0.36490283],
#        [ 0.20738262, -0.08901289, -0.6262239 , -0.61208035, -0.13075693,
#         -0.14617896, -0.1506819 , -0.17036816, -0.14945431,  0.13730621,
#         -0.08522192, -0.16600459,  0.12674592],
#        [-0.0178563 ,  0.53689028, -0.21417556,  0.06085941, -0.35179658,
#          0.19806835,  0.15229479, -0.20330102,  0.39905653,  0.06592568,
#         -0.42777141,  0.18412074, -0.23207086],
#        [ 0.26566365, -0.03521363,  0.14302547, -0.06610294, -0.72704851,
#          0.14931841,  0.10902584,  0.50070298, -0.13685982,  0.07643678,
#          0.17361452,  0.10116099,  0.1578688 ],
# ...

# %%
eig_vectors.T[0]
# Out:
# array([-0.1443294 ,  0.24518758,  0.00205106,  0.23932041, -0.14199204,
#        -0.39466085, -0.4229343 ,  0.2985331 , -0.31342949,  0.0886167 ,
#        -0.29671456, -0.37616741, -0.28675223])

# %%
project_X=X_scaler.dot(eig_vectors.T[0])
project_X
# Out:
# array([-3.31675081, -2.20946492, -2.51674015, -3.75706561, -1.00890849,
#        -3.05025392, -2.44908967, -2.05943687, -2.5108743 , -2.75362819,
#        -3.47973668, -1.7547529 , -2.11346234, -3.45815682, -4.31278391,
#        -2.3051882 , -2.17195527, -1.89897118, -3.54198508, -2.0845222 ,
#        -3.12440254, -1.08657007, -2.53522408, -1.64498834, -1.76157587,
#        -0.9900791 , -1.77527763, -1.23542396, -2.18840633, -2.25610898,
#        -2.50022003, -2.67741105, -1.62857912, -1.90269086, -1.41038853,
#        -1.90382623, -1.38486223, -1.12220741, -1.5021945 , -2.52980109,
#        -2.58809543, -0.66848199, -3.07080699, -0.46220914, -2.10135193,
#        -1.13616618, -2.72660096, -2.82133927, -2.00985085, -2.7074913 ,
#        -3.21491747, -2.85895983, -3.50560436, -2.22479138, -2.14698782,
#        -2.46932948, -2.74151791, -2.17374092, -3.13938015,  0.92858197,
#         1.54248014,  1.83624976, -0.03060683, -2.05026161,  0.60968083,
# ...

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %%
df.shape
# Out:
# (178, 14)

# %%
df=pd.DataFrame(project_X,columns=['PC1'])
df
# Out:
#           PC1
# 0   -3.316751
# 1   -2.209465
# 2   -2.516740
# 3   -3.757066
# 4   -1.008908
# ..        ...
# 173  3.370524
# 174  2.601956
# 175  2.677839
# 176  2.387017
# 177  3.208758
#
# [178 rows x 1 columns]

# %%
df['y_axis']=0.0
df['target']=y
df.shape
# Out:
# (178, 3)

# %%
sns.lmplot('PC1','y_axis',data=df,fit_reg=False,hue='target')
# here the setosa:-0 ,versicolor:-1 ,virginica:-2 ,

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=13)
# X--transformed to X_scaler
# then X_scaler trasnformed to project_X
project_X=pca.fit_transform(X_scaler)

# %% [markdown]
# # Reduced Dimentionality by PCA

# %%
# draw the plot
df=pd.DataFrame(project_X,columns=['PC1','PC2','PC3','PC4','PC5','PC5','PC6','PC7','PC7','PC8','PC9','PC10','PC11'])
df['y_axis']=0.0
df['target']=y
df
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC5       PC6  \
# 0    3.316751 -1.443463 -0.165739 -0.215631  0.693043 -0.223880  0.596427
# 1    2.209465  0.333393 -2.026457 -0.291358 -0.257655 -0.927120  0.053776
# 2    2.516740 -1.031151  0.982819  0.724902 -0.251033  0.549276  0.424205
# 3    3.757066 -2.756372 -0.176192  0.567983 -0.311842  0.114431 -0.383337
# 4    1.008908 -0.869831  2.026688 -0.409766  0.298458 -0.406520  0.444074
# ..        ...       ...       ...       ...       ...       ...       ...
# 173 -3.370524 -2.216289 -0.342570  1.058527 -0.574164 -1.108788  0.958416
# 174 -2.601956 -1.757229  0.207581  0.349496  0.255063 -0.026465  0.146894
# 175 -2.677839 -2.760899 -0.940942  0.312035  1.271355  0.273068  0.679235
# 176 -2.387017 -2.297347 -0.550696 -0.688285  0.813955  1.178783  0.633975
# 177 -3.208758 -2.768920  1.013914  0.596903 -0.895193  0.296092  0.005741
#
#           PC7       PC7       PC8       PC9      PC10      PC11  y_axis  \
# ...

# %%
df.shape
# Out:
# (178, 15)

# %%
sns.lmplot('PC1','y_axis',data=df1,fit_reg=False,hue='target')

# %%
# display dimentionality
print(X_scaler.shape)
print(project_X.shape)
# Out:
# (178, 13)
# (178, 13)

# %%
#since project_X contains only 1 column
# reshape it as 2D-array
data=project_X.reshape(-1,1)
data
# Out:
# array([[ 3.31675081],
#        [-1.44346263],
#        [-0.16573904],
#        ...,
#        [-0.22996433],
#        [-0.18878796],
#        [-0.32396472]])

# %%
print(project_X)
# Out:
# [[ 3.31675081e+00 -1.44346263e+00 -1.65739045e-01 ... -4.51563395e-01
#    5.40810414e-01 -6.62386309e-02]
#  [ 2.20946492e+00  3.33392887e-01 -2.02645737e+00 ... -1.42657306e-01
#    3.88237741e-01  3.63650247e-03]
#  [ 2.51674015e+00 -1.03115130e+00  9.82818670e-01 ... -2.86672847e-01
#    5.83573183e-04  2.17165104e-02]
#  ...
#  [-2.67783946e+00 -2.76089913e+00 -9.40941877e-01 ...  5.12492025e-01
#    6.98766451e-01  7.20776948e-02]
#  [-2.38701709e+00 -2.29734668e+00 -5.50696197e-01 ...  2.99821968e-01
#    3.39820654e-01 -2.18657605e-02]
#  [-3.20875816e+00 -2.76891957e+00  1.01391366e+00 ... -2.29964331e-01
#   -1.88787963e-01 -3.23964720e-01]]

# %%
# div the data into 2 parts
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df,y,test_size=0.2)

# %%
# Now the train the model using SVM
from sklearn.svm import SVC
model=SVC()
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
X_train.shape
# Out:
# (142, 13)

# %%
model.score(X_test,y_test)
# Out:
# 0.4166666666666667

# %%
X_test.shape
# Out:
# (36, 13)

# %%
#Find own data prediction
input=np.array([[1.00564972,0.09493026,0.21273976,-0.31198788,0.27232816,0.29073446,0.23815287,-0.15681042,0.13747022,0.549451,-0.07215255, 0.07275191,0.64735687]])
input
# Out:
# array([[ 1.00564972,  0.09493026,  0.21273976, -0.31198788,  0.27232816,
#          0.29073446,  0.23815287, -0.15681042,  0.13747022,  0.549451  ,
#         -0.07215255,  0.07275191,  0.64735687]])

# %%
# convert the inputs using StandardScaler
scaled=scaler.transform(input)
scaled
# Out:
# array([[-14.81696405,  -2.01203838,  -7.87278953,  -5.94772433,
#          -6.98406797,  -3.21167794,  -1.79822166,  -4.17929677,
#          -2.54652928,  -1.95030184,  -4.51721266,  -3.58609836,
#          -2.3764154 ]])

# %%
# convert the inputs using StandardScaler
scaled=scaler.transform(input)
scaled
# Out:
# array([[-14.81696405,  -2.01203838,  -7.87278953,  -5.94772433,
#          -6.98406797,  -3.21167794,  -1.79822166,  -4.17929677,
#          -2.54652928,  -1.95030184,  -4.51721266,  -3.58609836,
#          -2.3764154 ]])

# %%
#make prediction
model.predict(scaled)
# Out:
# array([2], dtype=int64)
